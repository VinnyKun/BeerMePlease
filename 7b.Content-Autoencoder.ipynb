# %% [markdown]
# # Training & Evaluation of Content‑Based Autoencoder Beer Recommender
#
# **Description:**
# This notebook loads the preprocessed beer content from `beer_content.csv`, transforms the aggregated review text into a 200‑feature TF‑IDF matrix, and defines a PyTorch autoencoder (inputDim=200, hiddenDim=512, embeddingDim=16) trained over 100 epochs with MSE loss and a learning‑rate scheduler. After evaluating reconstruction performance (MSE/RMSE), it extracts 16‑dimensional beer embeddings, performs sanity checks via cosine‑similarity comparisons and flavor‑profile queries, and saves the scripted model, embeddings tensor, and TF‑IDF vectorizer for downstream recommendation tasks.
#
# ---
#
# ## Overview
#
# - **Data Source:**
#   `beer_content.csv` containing `beer_id`, `name`, and `all_text` with top‑N keywords per beer.
#
# - **Objectives:**
#   1. Build a TF‑IDF feature matrix from cleaned beer text.
#   2. Train and validate an autoencoder to learn compact content embeddings.
#   3. Verify embedding quality with reconstruction metrics and manual sanity checks.
#   4. Export the trained model, embeddings, and vectorizer for inference.

# %% [markdown]
# ## Load Preprocessed Beer Content Data
#
# Load`beer_content.csv` into a pandas DataFrame `df`, prints the first few rows for inspection, and catches any exceptions if the file fails to load.

# %%
import pandas as pd

try:
    df = pd.read_csv('beer_content.csv')
    print("\final Data Sample:")
    print(df.head())
except Exception as e:
    print(f"Error loading reviews.csv: {e}")
# Out:
# inal Data Sample:
#    beer_id               name  \
# 0        6           Turbodog
# 1        7        Purple Haze
# 2       10         Dubbel Ale
# 3       17  Widmer Hefeweizen
# 4       30     Trois Pistoles
#
#                                             all_text
# 0  turbodog flavor flavors turbodog ale turbodog ...
# 1  haze flavors haze flavor flavour haze haze bre...
# 2  tasting dubbel dubbels flavored dubbel flavors...
# 3  flavorful hefeweizens flavorful hefeweizen hef...
# 4  beers trois brew trois breweries trois brews t...

# %%
import torch

device = torch.device(
    "cuda" if torch.cuda.is_available()
    else "mps"  if torch.backends.mps.is_available()
    else "cpu"
)

print(f"Using device: {device}")

if device.type == "cuda":
    idx = device.index or 0
    print("GPU name: ", torch.cuda.get_device_name(idx))
elif device.type == "mps":
    print("Running on Apple Silicon GPU via MPS")
else:
    print("Running on CPU")
# Out:
# Using device: mps
# Running on Apple Silicon GPU via MPS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   beer_id   500 non-null    int64
#  1   name      500 non-null    object
#  2   all_text  500 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 11.8+ KB

# %% [markdown]
# ## Generate TF‑IDF Feature Matrix
#
# Expands stop words with beer‑specific terms and applies a cleaning function before fitting a `TfidfVectorizer` (unigrams, `min_df=2`, `max_df=0.8`, `max_features=200`) to the beer text. After many iterations, we found that a feature range of 200–300 best balances expressiveness—>700 features caused embedding collapse (cosine similarity ≈99.99%), while too few features lost key tasting notes.

# %%
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS


non_taste_stop = {
    "us", "ca", "beer", "head", "taste", "pours", "like", "s", "t", "year", "round", "abv",'compared','10','11', '12',
    "availability", "yearround", "us","ca","just","really","overall","bottle","good", "nice", 'brewery',
    'brewing', 'brews', 'brew', 'style','drink', 'drinks', 'drinking', 'tastes', 'tasted', 'enjoy', 'enjoyable', 'okay',
    'recommended','appearance', 'looking','great', 'decent', 'pretty', 'amazing', 'excellent', 'best', 'favorite',
    'interesting', 'quality', 'look' 'beautiful', 'looks', 'look', 'exceptional', 'outstanding', 'slightly','expected',
    'definitely', 'pleasant', 'recommend', 'slightly', "awesome", "fantastic", "beautiful", "solid", "make", "review",
    'delightful','fine','quite','mix','makes','type','curious','liked','average','perfect','way','does','try','buy',
    'following','enjoyed','somewhat','definitely','wonderful','wonderfully','making','experience','specific','pure','odd',
    'impression','love', 'try', 'tried', 'extremely', 'alcoholic', 'appreciate', 'attractive', 'bad', 'better','compare',
    'especially', 'bold', 'characteristics', 'choice', 'color', 'colored','totally', 'unusual', 'usual', 'particular',
    'generally', 'different', 'drinker', 'finest', 'flavoring', 'flavours', 'kind','flavored', 'flavour', 
    'general', 'normal', 'opinion', 'pleasantly', 'prefer', 'regular','sample','gives','usually', 'brewed','honestly',
    'slight', 'smell', 'smells', 'smoothest', 'styles', 'traditional', 'typical', 'unique', 'worthy','breweries',
    'concerned', 'consider', 'considering', '12oz', '22oz', '2x', '750ml', '22','actually','absolutely', 'amazingly', 
    'exceptionally', 'extraordinary','fabulously', 'fantastically', 'incredibly', 'perfectly','remarkably', 'spectacular',
    'stunning', 'truly', 'totally','wonderfully', 'delightfully', 'deliciously', 'fascinating','exciting', 'fantastic',
    'disappointing','phenomenal','satisfying','enjoying','experienced', 'bottled', 'bottles', 'highly', 'surprisingly'
    'intriguing', 'noticeable', 'liking', 'lovely', 'impressed', 'impressive','intriguing', 'similar','remarkable',
    'reviewed','reviews', 'fairly','qualities','beautifully','drank','tastey', 'terrific','flavoured','surprisingly'
    'incredible','brewer','apparent','appealing', 'incredible', 'nicely', 'poured'
}

stopwords = ENGLISH_STOP_WORDS.union(non_taste_stop)


token_pattern = r'\b[a-z]{3,}\b'

def cleanText(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

df['clean_text'] = df['all_text'].apply(cleanText)
vectorizer = TfidfVectorizer(norm='l2', analyzer='word', ngram_range=(1,1), max_features=200, stop_words=list(stopwords),min_df=2, max_df=0.8)
tfidfMatrix = vectorizer.fit_transform(df['clean_text'])

print("Vocabulary size:", len(vectorizer.vocabulary_))
print("TF-IDF feature matrix shape:", tfidfMatrix.shape)
# Out:
# Vocabulary size: 200
# TF-IDF feature matrix shape: (500, 200)

# %% [markdown]
# ## Display Extracted TF‑IDF Features
#
# Prints the list of TF‑IDF feature names selected by the vectorizer, revealing the keywords used as input features for the autoencoder.

# %%
print(vectorizer.get_feature_names_out())
# Out:
# ['aged' 'alcohol' 'ale' 'ales' 'amber' 'ambers' 'american' 'apple'
#  'apricot' 'aroma' 'aromas' 'astringent' 'banana' 'bananas' 'barleywine'
#  'barleywines' 'beery' 'belgian' 'belgians' 'belgium' 'beverage' 'bitter'
#  'bittering' 'bitterness' 'bitters' 'bittersweet' 'black' 'bland' 'blend'
#  'blueberry' 'bock' 'bodied' 'booze' 'bourbon' 'bready' 'bright'
#  'brooklyn' 'brown' 'budweiser' 'candied' 'cantillon' 'caramel'
#  'caramelized' 'carbonation' 'champagne' 'cherry' 'chicory' 'chimay'
#  'chocolate' 'chocolatey' 'chouffe' 'christmas' 'cinnamon' 'citrus'
#  'citrusy' 'clear' 'cocoa' 'coffee' 'coors' 'coriander' 'cream'
#  'creaminess' 'creamy' 'crisp' 'darker' 'delirium' 'dessert' 'distinctive'
#  'doppelbock' 'dubbel' 'dubbels' 'espresso' 'feel' 'fermented' 'flanders'
#  'flavourful' 'fresh' 'fruit' 'fruitiness' 'fruity' 'german' 'glass'
#  'golden' 'grapefruit' 'gueuze' 'guinness' 'hazelnut' 'heavy' 'hefe'
#  'hefeweizen' 'hefeweizens' 'heineken' 'hop' 'hopped' 'hoppier'
#  'hoppiness' 'hoppy' 'hops' 'imperial' 'ipa' 'ipas' 'juicy' 'lager'
#  'lagers' 'lagunitas' 'lighter' 'malt' 'malted' 'malts' 'malty' 'marzen'
#  'medium' 'mellow' 'mild' 'miller' 'mixed' 'molasses' 'mouthfeel' 'oak'
#  'oatmeal' 'oktoberfest' 'oktoberfests' 'old' 'orange' 'palate' 'pale'
#  'pils' 'pilsener' 'pilsner' 'pilsners' 'pine' 'porter' 'porters'
#  'pumpkin' 'pumpkins' 'quad' 'raisin' 'raisins' 'raspberries' 'raspberry'
#  'rauchbier' 'red' 'reddish' 'roasted' 'roastiness' 'roasty' 'rochefort'
#  'rye' 'saison' 'saisons' 'scent' 'scotch' 'scottish' 'seasonal' 'smoke'
#  'smoked' 'smoky' 'smooth' 'sour' 'sourness' 'spice' 'spices' 'standard'
#  'stout' 'stouts' 'strong' 'styled' 'subtle' 'sugar' 'sugary' 'summer'
#  'surprisingly' 'sweet' 'sweeter' 'sweetness' 'syrupy' 'tart' 'tartness'
#  'toffee' 'trappist' 'tripel' 'tripels' 'unibroue' 'vanilla' 'watery'
#  'weihenstephan' 'weihenstephaner' 'weizen' 'weizenbock' 'wheat' 'whiskey'
#  'white' 'wine' 'winter' 'witbier' 'yeast' 'yeastiness' 'yeasty' 'yeti'
#  'yuengling']

# %% [markdown]
# ## Prepare Data for Autoencoder
#
# Imports PyTorch and related utilities, converts the TF‑IDF matrix to a dense NumPy array, performs an 80/20 train‑validation split, and wraps the resulting arrays as PyTorch tensors (`XTrain`, `XVal`).

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split

X = tfidfMatrix.toarray()

XTrainNp, XValNp = train_test_split(X, test_size=0.2, random_state=42)
XTrain = torch.tensor(XTrainNp, dtype=torch.float)
XVal = torch.tensor(XValNp, dtype=torch.float)

# %% [markdown]
# ## Create PyTorch Dataset and DataLoaders
#
# Defines a `BeerDataset` class for wrapping feature tensors, then instantiates training and validation datasets and creates `DataLoader`s (batch size 32, shuffled for training, sequential for validation).

# %%
class BeerDataset(Dataset):
    def __init__(self, features):
        self.features = features
        
    def __len__(self):
        return self.features.size(0)
    
    def __getitem__(self, idx):
        return self.features[idx]

trainDataset = BeerDataset(XTrain)
valDataset = BeerDataset(XVal)

trainLoader = DataLoader(trainDataset, batch_size=32, shuffle=True)
valLoader = DataLoader(valDataset, batch_size=32, shuffle=False)

# %% [markdown]
# ## Define Autoencoder and Training Setup
#
# The `BeerAutoencoder` class is defined with an encoder (input→hidden→embedding) and decoder (embedding→hidden→output with sigmoid). A model instance is moved to `device`, and training components are configured: MSE loss, Adam optimizer (lr=1e-3, weight_decay=1e-5), and a ReduceLROnPlateau learning‑rate scheduler.
#
# `BeerAutoencoder` is instantiated with `inputDim=len(vectorizer.vocabulary_)` (200 features), `hiddenDim=512`, and `embeddingDim=16`—a configuration determined via extensive experimentation on hidden/embedding dimensions and feature counts that balanced reconstruction quality and cosine similarity variance.

# %%
class BeerAutoencoder(nn.Module):
    def __init__(self, inputDim=500, hiddenDim=256, embeddingDim=32):
        super(BeerAutoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(inputDim, hiddenDim),
            nn.ReLU(),
            nn.Linear(hiddenDim, embeddingDim)
        )
        self.decoder = nn.Sequential(
            nn.Linear(embeddingDim, hiddenDim),
            nn.ReLU(),
            nn.Linear(hiddenDim, inputDim),
            nn.Sigmoid()  # Output values between 0 and 1
        )
    
    def forward(self, x):
        embedding = self.encoder(x)
        reconstruction = self.decoder(embedding)
        return reconstruction, embedding

model = BeerAutoencoder(inputDim=len(vectorizer.vocabulary_), hiddenDim=512, embeddingDim=16)
model = model.to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-5)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 
                                                       mode='min', 
                                                       factor=0.5, 
                                                       patience=5)

# %% [markdown]
# ## Train Autoencoder and Plot Loss
#
# Runs a 100‑epoch training loop that computes MSE reconstruction loss on each batch, backpropagates gradients, updates model parameters, records the average loss per epoch, and adjusts the learning rate via the ReduceLROnPlateau scheduler. Concludes by plotting the epoch‑wise training loss curve with matplotlib to assess convergence.

# %%
epochs = 100
losses = [] #added to store avg loss per epoch

for epoch in range(epochs):
    model.train()
    totalLoss = 0.0
    for batch in trainLoader:
        optimizer.zero_grad()
        batch = batch.to(device)
        reconstruction, _ = model(batch)
        loss = criterion(reconstruction, batch)
        loss.backward()
        optimizer.step()
        totalLoss += loss.item()
        
    avgLoss = totalLoss / len(trainLoader)
    losses.append(avgLoss)
    print(f"Epoch {epoch+1}/{epochs}, Loss: {avgLoss:.4f}")

    scheduler.step(avgLoss)
    current_lr = optimizer.param_groups[0]['lr']
    print(f"           → current LR: {current_lr:.5f}")

#for visualising the losses
import matplotlib.pyplot as plt

plt.plot(losses)
plt.title("Training Loss Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.show()
# Out:
# Epoch 1/100, Loss: 0.1874
#            → current LR: 0.00100
# Epoch 2/100, Loss: 0.0399
#            → current LR: 0.00100
# Epoch 3/100, Loss: 0.0049
#            → current LR: 0.00100
# Epoch 4/100, Loss: 0.0048
#            → current LR: 0.00100
# Epoch 5/100, Loss: 0.0048
#            → current LR: 0.00100
# Epoch 6/100, Loss: 0.0047
#            → current LR: 0.00100
# Epoch 7/100, Loss: 0.0047
#            → current LR: 0.00100
# Epoch 8/100, Loss: 0.0046
#            → current LR: 0.00100
# Epoch 9/100, Loss: 0.0046
#            → current LR: 0.00100
# Epoch 10/100, Loss: 0.0046
#            → current LR: 0.00100
# Epoch 11/100, Loss: 0.0045
#            → current LR: 0.00100
# Epoch 12/100, Loss: 0.0045
#            → current LR: 0.00100
# Epoch 13/100, Loss: 0.0045
#            → current LR: 0.00100
# Epoch 14/100, Loss: 0.0043
#            → current LR: 0.00100
# Epoch 15/100, Loss: 0.0042
#            → current LR: 0.00100
# Epoch 16/100, Loss: 0.0040
#            → current LR: 0.00100
# Epoch 17/100, Loss: 0.0038
#            → current LR: 0.00100
# Epoch 18/100, Loss: 0.0036
#            → current LR: 0.00100
# Epoch 19/100, Loss: 0.0034
#            → current LR: 0.00100
# Epoch 20/100, Loss: 0.0033
#            → current LR: 0.00100
# Epoch 21/100, Loss: 0.0033
#            → current LR: 0.00100
# Epoch 22/100, Loss: 0.0033
#            → current LR: 0.00100
# Epoch 23/100, Loss: 0.0033
#            → current LR: 0.00100
# Epoch 24/100, Loss: 0.0033
#            → current LR: 0.00100
# Epoch 25/100, Loss: 0.0032
#            → current LR: 0.00100
# Epoch 26/100, Loss: 0.0032
#            → current LR: 0.00100
# Epoch 27/100, Loss: 0.0032
#            → current LR: 0.00100
# Epoch 28/100, Loss: 0.0032
#            → current LR: 0.00100
# Epoch 29/100, Loss: 0.0032
#            → current LR: 0.00100
# Epoch 30/100, Loss: 0.0032
#            → current LR: 0.00100
# Epoch 31/100, Loss: 0.0031
#            → current LR: 0.00100
# Epoch 32/100, Loss: 0.0031
#            → current LR: 0.00100
# Epoch 33/100, Loss: 0.0030
#            → current LR: 0.00100
# Epoch 34/100, Loss: 0.0030
#            → current LR: 0.00100
# Epoch 35/100, Loss: 0.0029
#            → current LR: 0.00100
# Epoch 36/100, Loss: 0.0029
#            → current LR: 0.00100
# Epoch 37/100, Loss: 0.0029
#            → current LR: 0.00100
# Epoch 38/100, Loss: 0.0029
#            → current LR: 0.00100
# Epoch 39/100, Loss: 0.0028
#            → current LR: 0.00100
# Epoch 40/100, Loss: 0.0028
#            → current LR: 0.00100
# Epoch 41/100, Loss: 0.0028
#            → current LR: 0.00100
# Epoch 42/100, Loss: 0.0028
#            → current LR: 0.00100
# Epoch 43/100, Loss: 0.0027
#            → current LR: 0.00100
# Epoch 44/100, Loss: 0.0027
#            → current LR: 0.00100
# Epoch 45/100, Loss: 0.0026
#            → current LR: 0.00100
# Epoch 46/100, Loss: 0.0026
#            → current LR: 0.00100
# Epoch 47/100, Loss: 0.0026
#            → current LR: 0.00100
# Epoch 48/100, Loss: 0.0025
#            → current LR: 0.00100
# Epoch 49/100, Loss: 0.0025
#            → current LR: 0.00100
# Epoch 50/100, Loss: 0.0025
#            → current LR: 0.00100
# Epoch 51/100, Loss: 0.0025
#            → current LR: 0.00100
# Epoch 52/100, Loss: 0.0026
#            → current LR: 0.00100
# Epoch 53/100, Loss: 0.0025
#            → current LR: 0.00100
# Epoch 54/100, Loss: 0.0026
#            → current LR: 0.00100
# Epoch 55/100, Loss: 0.0025
#            → current LR: 0.00100
# Epoch 56/100, Loss: 0.0025
#            → current LR: 0.00100
# Epoch 57/100, Loss: 0.0025
#            → current LR: 0.00100
# Epoch 58/100, Loss: 0.0025
#            → current LR: 0.00100
# Epoch 59/100, Loss: 0.0025
#            → current LR: 0.00100
# Epoch 60/100, Loss: 0.0025
#            → current LR: 0.00100
# Epoch 61/100, Loss: 0.0025
#            → current LR: 0.00050
# Epoch 62/100, Loss: 0.0025
#            → current LR: 0.00050
# Epoch 63/100, Loss: 0.0025
#            → current LR: 0.00050
# Epoch 64/100, Loss: 0.0025
#            → current LR: 0.00050
# Epoch 65/100, Loss: 0.0025
#            → current LR: 0.00050
# Epoch 66/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 67/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 68/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 69/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 70/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 71/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 72/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 73/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 74/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 75/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 76/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 77/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 78/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 79/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 80/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 81/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 82/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 83/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 84/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 85/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 86/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 87/100, Loss: 0.0024
#            → current LR: 0.00050
# Epoch 88/100, Loss: 0.0024
#            → current LR: 0.00025
# Epoch 89/100, Loss: 0.0024
#            → current LR: 0.00025
# Epoch 90/100, Loss: 0.0023
#            → current LR: 0.00025
# Epoch 91/100, Loss: 0.0024
#            → current LR: 0.00025
# Epoch 92/100, Loss: 0.0024
#            → current LR: 0.00025
# Epoch 93/100, Loss: 0.0023
#            → current LR: 0.00025
# Epoch 94/100, Loss: 0.0023
#            → current LR: 0.00025
# Epoch 95/100, Loss: 0.0024
#            → current LR: 0.00025
# Epoch 96/100, Loss: 0.0024
#            → current LR: 0.00025
# Epoch 97/100, Loss: 0.0024
#            → current LR: 0.00025
# Epoch 98/100, Loss: 0.0024
#            → current LR: 0.00025
# Epoch 99/100, Loss: 0.0023
#            → current LR: 0.00025
# Epoch 100/100, Loss: 0.0023
#            → current LR: 0.00025

# %% [markdown]
# ## Validate Autoencoder Performance
#
# Switch to evaluation mode, computes batch-wise reconstruction MSE on the validation set without gradients, aggregates losses to calculate average MSE and RMSE, and prints the metrics.

# %%
# Validate the model
model.eval()
valLoss = 0.0
with torch.no_grad():
    for batch in valLoader:
        batch = batch.to(device)
        reconstruction, _ = model(batch)
        loss = criterion(reconstruction, batch)
        valLoss += loss.item() * batch.size(0)
        
avgValLoss = valLoss / len(valDataset)
rmse = avgValLoss ** 0.5
print(f"Validation MSE: {avgValLoss:.4f}")
print(f"Validation RMSE: {rmse:.4f}")
# Out:
# Validation MSE: 0.0029
# Validation RMSE: 0.0535

# %% [markdown]
# ## Sanity Check Utilities
#
# - Computes embeddings for all beers and stores them in `beerEmbeddings`
# - `getBeerDetailsByIndex(beerIndex)`: prints the beer’s ID and name
# - `getBeersDetailsByIndices(beerIndices, similarity)`: lists beers with their cosine similarity scores
# - `getTopKSimilarBeersByIndex(beerIndex, topK)`: retrieves and displays the top‑K similar beers by index
# - `getTopKSimilarBeersByQuery(query, topK)`: transforms a text query into an embedding and displays the top‑K similar beers

# %%
# utility methods
XTensor = torch.tensor(X, dtype=torch.float).to(device)
model.eval()
with torch.no_grad():
    _, beerEmbeddings = model(XTensor)  # Obtain embeddings for all beers, shape: (500, 16)

def getBeerDetailsByIndex(beerIndex):
    beer_id = df.iloc[beerIndex]['beer_id']
    name = df.iloc[beerIndex]['name']
    print("Beer ID:", beer_id, "Name:", name)

def getBeersDetailsByIndices(beerIndices,similarity):
    for index in beerIndices:
        beer_id = df.iloc[index.item()]['beer_id']
        name    = df.iloc[index.item()]['name']
        print(f"{beer_id:5d} | {name:30s} | simlarity={similarity[index.item()]:.3f}")


def getTopKSimilarBeersByIndex(beerIndex, topK):
    targetEmbedding = beerEmbeddings[beerIndex].unsqueeze(0)
    cosSim = F.cosine_similarity(targetEmbedding, beerEmbeddings)
    cosSim[beerIndex] = -1
    _, topIndices = torch.topk(cosSim, k=topK)
    getBeerDetailsByIndex(beerIndex)
    getBeersDetailsByIndices(topIndices,cosSim)
    return topIndices

def getTopKSimilarBeersByQuery(query, topK):
    queryClean = cleanText(query)
    queryTfidf = vectorizer.transform([queryClean])
    queryTensor = torch.tensor(queryTfidf.toarray(), dtype=torch.float).to(device)

    model.eval()
    with torch.no_grad():
        _, queryEmbedding = model(queryTensor)
    similarity = F.cosine_similarity(queryEmbedding, beerEmbeddings)
    _, topIndicesTensor = torch.topk(similarity, topK)
    getBeersDetailsByIndices(topIndicesTensor, similarity)
    return topIndicesTensor

# %% [markdown]
# ## Inspect Full Cosine Similarity Distribution
#
# Calls `getTopKSimilarBeersByIndex(112, 500)` to compute and display cosine similarities between beer index 112 and all 500 beers, printing the full range of similarity scores for a comprehensive sanity check. Upon visual inspection, the highest‑scoring beers clearly share meaningful flavor‑profile similarities with the target, while the lowest‑scoring beers are appropriately dissimilar.

# %%
# finding similar beer based on beer -> passed sanity check
getTopKSimilarBeersByIndex(110,500)
# Out:
# Beer ID: 680 Name: Brooklyn Black Chocolate Stout
# 49286 | Mokah                          | simlarity=1.000
#   283 | Sierra Nevada Stout            | simlarity=1.000
# 94350 | Bomb!                          | simlarity=1.000
# 52128 | Java Head Stout                | simlarity=1.000
#  3434 | Milk Stout                     | simlarity=1.000
# 37265 | Black Note Stout               | simlarity=1.000
#  1117 | Kalamazoo Stout                | simlarity=1.000
# 41626 | Double Stout                   | simlarity=1.000
#  8023 | Siberian Night Imperial Stout  | simlarity=1.000
#  1013 | Storm King Stout               | simlarity=1.000
#  1658 | Big Bear Black Stout           | simlarity=1.000
# 34483 | Ten FIDY                       | simlarity=1.000
#  2403 | Double Cream Stout             | simlarity=1.000
# 46987 | Beer Geek Brunch Weasel        | simlarity=1.000
#   703 | Murphy's Irish Stout           | simlarity=1.000
#   356 | Imperial Stout                 | simlarity=1.000
# 47360 | Samuel Adams Imperial Stout    | simlarity=1.000
# 86149 | Narwhal Imperial Stout         | simlarity=1.000
# 47658 | CBS (Canadian Breakfast Stout) | simlarity=1.000
# 15813 | Blackout Stout                 | simlarity=1.000
#  7520 | Dark Lord Imperial Stout       | simlarity=1.000
# 34420 | The Abyss                      | simlarity=1.000
#  1444 | Expedition Stout               | simlarity=1.000
# 19960 | KBS (Kentucky Breakfast Stout) | simlarity=1.000
# 20216 | Milk Stout                     | simlarity=1.000
# 19216 | Oak Aged Yeti Imperial Stout   | simlarity=1.000
#   412 | Old Rasputin                   | simlarity=1.000
# 19667 | Peg Leg Imperial Stout         | simlarity=1.000
#   185 | Smuttynose Imperial Stout (Big Beer Series) | simlarity=1.000
#  1118 | Chocolate Stout                | simlarity=1.000
#  1115 | Lion Stout                     | simlarity=1.000
# 11757 | Breakfast Stout                | simlarity=1.000
#   782 | Imperial Stout                 | simlarity=1.000
# 34094 | Older Viscosity                | simlarity=1.000
# 45073 | Plead The 5th Imperial Stout   | simlarity=1.000
#  1879 | Samuel Adams Cream Stout       | simlarity=1.000
#  3833 | Speedway Stout                 | simlarity=1.000
# 20445 | Cappuccino Stout               | simlarity=0.999
# 33127 | Darkness                       | simlarity=0.999
# 33644 | B.O.R.I.S. The Crusher         | simlarity=0.999
#  2392 | World Wide Stout               | simlarity=0.999
# 20539 | Stoudt's Fat Dog (Imperial Oatmeal Stout) | simlarity=0.999
# 31613 | Old Viscosity                  | simlarity=0.999
# 59151 | Miles Davis' Bitches Brew      | simlarity=0.999
# 56469 | Dark Truth Imperial Stout      | simlarity=0.999
#  1373 | Lagunitas Imperial Stout       | simlarity=0.999
# 47022 | Hunahpu's Imperial Stout       | simlarity=0.999
#   197 | Obsidian Stout                 | simlarity=0.999
#   571 | Oatmeal Stout                  | simlarity=0.999
#    73 | Young's Double Chocolate Stout | simlarity=0.999
# 41815 | Parabola                       | simlarity=0.999
#   875 | Old Engine Oil Black Ale       | simlarity=0.999
#  2511 | Cherry Stout                   | simlarity=0.999
# 45897 | Velvet Merlin Oatmeal Stout    | simlarity=0.999
# 12013 | Yeti Imperial Stout            | simlarity=0.998
# 10325 | Péché Mortel                   | simlarity=0.998
#   650 | Guinness Extra Stout (Original) | simlarity=0.998
# 38334 | Black Albert                   | simlarity=0.996
# 21950 | W-n-B Coffee Oatmeal Imperial Stout | simlarity=0.995
# 40149 | Brooklyn Black OPS             | simlarity=0.994
#   615 | Barney Flats Oatmeal Stout     | simlarity=0.994
#   752 | Guinness Foreign Extra Stout   | simlarity=0.993
# 43687 | Crème Brûlée Imperial Milk Stout (Blackwater Series) | simlarity=0.992
# 57747 | Bourbon County Brand Coffee Stout | simlarity=0.991
# 50176 | Chocolate Oak Aged Yeti        | simlarity=0.991
# 33832 | Palo Santo Marron              | simlarity=0.990
# 28877 | Beer Geek Breakfast            | simlarity=0.988
# 21300 | Samuel Adams Black Lager       | simlarity=0.986
# 40051 | Black                          | simlarity=0.984
#  1774 | Schwarzbier                    | simlarity=0.978
#  2010 | Java Stout                     | simlarity=0.975
# 40058 | Choklat (Blackwater Series)    | simlarity=0.974
#  5428 | Dragon's Milk                  | simlarity=0.970
#  8322 | New Holland The Poet           | simlarity=0.967
#   754 | Guinness Draught               | simlarity=0.967
# 16062 | Brewer's Reserve Bourbon Barrel Stout | simlarity=0.966
# 10672 | Bourbon County Brand Stout     | simlarity=0.965
# 30764 | Coffee Bender                  | simlarity=0.960
#  1914 | 1554 Black Lager               | simlarity=0.955
# 14309 | Samuel Adams Chocolate Bock    | simlarity=0.955
# 41702 | Theobroma                      | simlarity=0.954
#  1545 | Trappist Westvleteren 12 (XII) | simlarity=0.947
# 34306 | Pannepot                       | simlarity=0.947
# 48505 | Victory At Sea Imperial Porter with Coffee & Vanilla | simlarity=0.941
# 43670 | Bourbon Barrel Quad Barrel-Aged Ale (BBQ) | simlarity=0.940
# 16909 | Curieux                        | simlarity=0.940
#  7438 | Alpha Klaus Christmas (Xmas) Porter | simlarity=0.928
# 56973 | Shakespeare Oatmeal Stout      | simlarity=0.924
#   808 | Weihenstephaner Hefeweissbier Dunkel | simlarity=0.923
#   224 | Schneider Weisse Tap 6 Unser Aventinus | simlarity=0.923
#  5488 | Wells Banana Bread Beer        | simlarity=0.922
#   221 | Fuller's London Porter         | simlarity=0.922
#  2137 | Leffe Blonde                   | simlarity=0.922
#    10 | Dubbel Ale                     | simlarity=0.920
#  1855 | Prior 8                        | simlarity=0.920
# 37795 | Coconut Hiwa Porter            | simlarity=0.919
#   727 | Aecht Schlenkerla Rauchbier Märzen | simlarity=0.919
#  1769 | Alaskan Smoked Porter          | simlarity=0.919
#    90 | Smoked Porter                  | simlarity=0.918
#   857 | Trappist Westvleteren 8 (VIII) | simlarity=0.917
# 27800 | Vanilla Porter                 | simlarity=0.916
#   353 | Mocha Porter                   | simlarity=0.916
#  3842 | Trappistes Rochefort 6         | simlarity=0.914
#   645 | Trappistes Rochefort 10        | simlarity=0.914
#   667 | Negra Modelo                   | simlarity=0.913
#   924 | Franziskaner Hefe-Weisse Dunkel | simlarity=0.913
#  2566 | Maredsous 10 - Triple          | simlarity=0.913
#   622 | Robust Porter                  | simlarity=0.912
#   572 | Taddy Porter                   | simlarity=0.912
#  9689 | White Rascal                   | simlarity=0.912
# 33183 | Pipeline Porter                | simlarity=0.911
#  7348 | Porter                         | simlarity=0.911
# 24071 | Gonzo Imperial Porter          | simlarity=0.911
#   722 | Tripel                         | simlarity=0.910
#   646 | Westmalle Trappist Tripel      | simlarity=0.910
#  1577 | Wisconsin Belgian Red          | simlarity=0.910
#   674 | Westmalle Trappist Dubbel      | simlarity=0.908
#  6073 | Merry Monks                    | simlarity=0.908
#  1912 | Abbey                          | simlarity=0.908
#  3635 | La Terrible                    | simlarity=0.907
#  1287 | Porter                         | simlarity=0.907
#  1346 | Chimay Tripel (White)          | simlarity=0.907
#   198 | Black Butte Porter             | simlarity=0.906
# 35036 | Backwoods Bastard              | simlarity=0.906
# 42723 | Espresso Oak Aged Yeti Imperial Stout | simlarity=0.905
#    61 | Anchor Porter                  | simlarity=0.905
# 20564 | Samuel Adams Holiday Porter    | simlarity=0.905
#   672 | Chimay Première (Red)          | simlarity=0.905
#   449 | Stella Artois                  | simlarity=0.904
#  1632 | Cantillon Kriek 100% Lambic    | simlarity=0.904
# 16807 | Père Jacques                   | simlarity=0.903
#   226 | Edmund Fitzgerald Porter       | simlarity=0.903
#   206 | Road Dog Porter                | simlarity=0.902
#   279 | Porter                         | simlarity=0.902
#   132 | Ayinger Bräu Weisse            | simlarity=0.901
# 46070 | Back In Black                  | simlarity=0.900
#  1153 | Chicory Stout                  | simlarity=0.899
#  1324 | Aecht Schlenkerla Rauchbier Urbock | simlarity=0.899
#   108 | Samuel Adams Cherry Wheat      | simlarity=0.899
#  3089 | Raison D'Extra                 | simlarity=0.899
#    59 | White                          | simlarity=0.899
#  1385 | Delirium Tremens               | simlarity=0.899
# 48434 | Kellerweis                     | simlarity=0.899
#  1836 | La Chouffe                     | simlarity=0.898
#  1256 | Paulaner Hefe-Weissbier Naturtrüb | simlarity=0.897
#  1917 | La Folie                       | simlarity=0.897
#  5328 | Longboard Island Lager         | simlarity=0.896
#   712 | Weihenstephaner Original       | simlarity=0.895
#  2434 | Erdinger Weissbier             | simlarity=0.895
#  1790 | Peroni Nastro Azzurro          | simlarity=0.895
#   760 | Weihenstephaner Kristallweissbier | simlarity=0.894
#  3280 | Schneider Weisse Tap 7 Unser Original | simlarity=0.894
#  1054 | Trippel                        | simlarity=0.894
#   656 | Tripel Karmeliet               | simlarity=0.894
#   772 | Hacker-Pschorr Hefe Weisse Naturtrüb | simlarity=0.894
#  2512 | Chimay Grande Réserve (Blue)   | simlarity=0.894
#  1008 | Moonglow Weizenbock            | simlarity=0.894
#  1946 | Franziskaner Hefe-Weisse       | simlarity=0.894
#  6715 | Budweiser Budvar B:Original    | simlarity=0.893
#    65 | Budweiser                      | simlarity=0.893
#   837 | Coors Light                    | simlarity=0.893
#  9474 | Temptation                     | simlarity=0.893
# 35720 | Festina Pêche                  | simlarity=0.893
#  2249 | Hefeweizen                     | simlarity=0.892
#   246 | Heineken Lager Beer            | simlarity=0.892
# 35625 | Weihenstephaner Vitus          | simlarity=0.892
# 22227 | Supplication                   | simlarity=0.892
#   580 | Miller High Life               | simlarity=0.892
#  1587 | Midas Touch                    | simlarity=0.892
#   779 | Weihenstephaner Korbinian      | simlarity=0.891
#   731 | Weihenstephaner Hefeweissbier  | simlarity=0.891
# 35328 | Brooklyn Local 1               | simlarity=0.891
#  1276 | Coors Banquet                  | simlarity=0.891
#    17 | Widmer Hefeweizen              | simlarity=0.890
#   599 | Lindemans Framboise            | simlarity=0.889
# 39908 | Shock Top Belgian White        | simlarity=0.889
#   131 | Celebrator                     | simlarity=0.889
#  4109 | Troegenator                    | simlarity=0.888
#  1402 | La Trappe Quadrupel (Koningshoeven / Dominus) | simlarity=0.888
# 16506 | Witte Wheat Ale                | simlarity=0.888
#  1352 | Shiner Bock                    | simlarity=0.888
#  1585 | Raspberry Tart                 | simlarity=0.887
# 29015 | Leinenkugel's Sunset Wheat     | simlarity=0.887
#   387 | Salvator Doppel Bock           | simlarity=0.887
# 47785 | Samuel Adams Double Bock (Imperial Series) | simlarity=0.886
#   689 | Red Stripe Jamaican Lager      | simlarity=0.886
#  6104 | Grand Cru Oude Gueuze Cuvée René | simlarity=0.886
#  1331 | Pabst Blue Ribbon (PBR)        | simlarity=0.886
#   232 | Corona Extra                   | simlarity=0.886
#  1703 | Cantillon Gueuze 100% Lambic   | simlarity=0.885
#   332 | Miller Lite                    | simlarity=0.885
#  2732 | Consecrator Doppelbock         | simlarity=0.885
# 10482 | Monk's Café Flemish Sour Ale   | simlarity=0.884
#  2557 | Cantillon Rosé De Gambrinus    | simlarity=0.884
#   862 | Harp Lager                     | simlarity=0.884
#  1320 | Bud Light                      | simlarity=0.883
#  1717 | Saison Dupont                  | simlarity=0.883
# 18975 | Oro De Calabaza                | simlarity=0.883
#  1351 | Yuengling Traditional Lager    | simlarity=0.883
#  3523 | Éphémère (Apple)               | simlarity=0.882
#   935 | Premium German Pilsener        | simlarity=0.882
#  1339 | Hazelnut Brown Nectar          | simlarity=0.881
#    74 | Post Road Pumpkin Ale          | simlarity=0.881
#  1641 | Premium Beer                   | simlarity=0.881
#    34 | La Fin Du Monde                | simlarity=0.880
#  1932 | Pumpkinhead Ale                | simlarity=0.880
#   141 | Hennepin                       | simlarity=0.880
# 18199 | Insanity - Oak Barrel-Aged     | simlarity=0.879
#   448 | Tripel Ale                     | simlarity=0.879
# 36333 | Saison-Brett                   | simlarity=0.879
#  1421 | Delirium Nocturnum             | simlarity=0.879
#   570 | Brooklyn Oktoberfest           | simlarity=0.879
# 38394 | Pumking                        | simlarity=0.879
#  6260 | Punkin Ale                     | simlarity=0.878
# 11819 | Pumpkin Ale                    | simlarity=0.878
#   100 | Blue Moon Harvest Moon Pumpkin Ale | simlarity=0.878
#   695 | Duvel Belgian Golden Ale       | simlarity=0.878
# 25880 | Imperial Pumpkin Ale           | simlarity=0.878
#   429 | Pilsner Urquell                | simlarity=0.878
#  5057 | Fantôme Saison                 | simlarity=0.878
#  1017 | Festbier                       | simlarity=0.878
#   102 | Samuel Adams Octoberfest       | simlarity=0.877
#   776 | Samichlaus Classic Bier        | simlarity=0.877
#  1361 | Ayinger Oktober Fest-Märzen    | simlarity=0.877
#  3558 | Sierra Nevada Summerfest       | simlarity=0.876
#  6305 | Drie Fonteinen Oude Geuze      | simlarity=0.876
# 14712 | Old Chub - Scottish Style Ale  | simlarity=0.876
#  1934 | Schneider Aventinus Weizen-Eisbock | simlarity=0.876
#   409 | Scrimshaw Pilsner              | simlarity=0.876
#    30 | Trois Pistoles                 | simlarity=0.876
#   582 | Spaten Oktoberfestbier Ur-Märzen | simlarity=0.875
# 39621 | The Sixth Glass Quadrupel Ale  | simlarity=0.874
#  1212 | Blue Moon Belgian White        | simlarity=0.874
#   228 | Dortmunder Gold                | simlarity=0.874
#    99 | Spaten Optimator               | simlarity=0.874
# 19589 | Lagunitas PILS (Czech Style Pilsner) | simlarity=0.874
#    31 | Blanche De Chambly             | simlarity=0.874
#   694 | Don De Dieu                    | simlarity=0.873
#  1856 | Pater 6                        | simlarity=0.873
#  1010 | Prima Pils                     | simlarity=0.873
#  4318 | Matilda                        | simlarity=0.872
# 48824 | Sofie                          | simlarity=0.872
#   142 | Abbey Ale                      | simlarity=0.871
#  1708 | Abt 12                         | simlarity=0.870
# 54904 | Samuel Adams Noble Pils        | simlarity=0.870
#  1903 | Samuel Adams Cranberry Lambic  | simlarity=0.870
# 74986 | Lagunitas Sucks                | simlarity=0.869
#     7 | Purple Haze                    | simlarity=0.867
#  2014 | The Reverend                   | simlarity=0.867
#  1003 | Golden Monkey                  | simlarity=0.866
#   402 | Skull Splitter                 | simlarity=0.864
#   386 | Paulaner Oktoberfest Bier      | simlarity=0.863
#   635 | Kwak                           | simlarity=0.862
#  7463 | Dirty Bastard                  | simlarity=0.861
#  3457 | Three Philosophers             | simlarity=0.860
#  1696 | Trappistes Rochefort 8         | simlarity=0.860
#  1503 | Sam Adams Light                | simlarity=0.860
#   148 | Brooklyn Lager                 | simlarity=0.860
# 48139 | Mama's Little Yella Pils       | simlarity=0.855
# 12770 | Damnation                      | simlarity=0.855
#   248 | Hoegaarden Original White Ale  | simlarity=0.852
#  6947 | Cuvée Van De Keizer Blauw (Blue) | simlarity=0.849
# 24905 | Curmudgeon                     | simlarity=0.848
#  1543 | Sawtooth                       | simlarity=0.848
#   234 | Hacker-Pschorr Original Oktoberfest Amber Märzen | simlarity=0.845
# 50570 | Tank 7 Farmhouse Ale           | simlarity=0.844
#  5948 | Terrapin Rye Pale Ale          | simlarity=0.840
# 37774 | Schneider Weisse Tap 5 Schneider & Brooklyner Hopfenweisse | simlarity=0.839
# 76816 | Sierra Nevada Ruthless Rye IPA | simlarity=0.838
# 30282 | Brother Thelonious             | simlarity=0.836
#  1119 | Redhook ESB                    | simlarity=0.833
#   156 | Piraat                         | simlarity=0.832
#   567 | Rolling Rock Extra Pale        | simlarity=0.831
#  2347 | Delirium Noël                  | simlarity=0.831
#  2296 | Moose Drool Brown Ale          | simlarity=0.830
#  3951 | ApriHop                        | simlarity=0.830
#   219 | Fuller's ESB                   | simlarity=0.827
#   104 | Samuel Adams Boston Lager      | simlarity=0.827
#   363 | American Amber Ale             | simlarity=0.827
#   101 | Samuel Adams Winter Lager      | simlarity=0.822
# 19314 | La Roja                        | simlarity=0.820
#   171 | Dos Equis Amber Lager          | simlarity=0.817
# 17141 | 312 Urban Wheat                | simlarity=0.815
#  1094 | Oberon Ale                     | simlarity=0.815
#  1159 | Robert The Bruce               | simlarity=0.808
#     6 | Turbodog                       | simlarity=0.805
#   411 | Pranqster                      | simlarity=0.802
#  3295 | Old Jubilation                 | simlarity=0.800
#  2178 | Jubelale                       | simlarity=0.798
#   236 | Hobgoblin                      | simlarity=0.798
#   229 | Eliot Ness                     | simlarity=0.797
# 60420 | Sierra Nevada Tumbler Autumn Brown Ale | simlarity=0.796
# 51480 | Brooklyn Sorachi Ace           | simlarity=0.790
# 16074 | Red's Rye IPA                  | simlarity=0.788
#   673 | Rodenbach Grand Cru            | simlarity=0.788
#   155 | Gulden Draak                   | simlarity=0.787
#   593 | Rare Vos Amber Ale             | simlarity=0.787
#   909 | George Killian's Irish Red     | simlarity=0.787
# 39286 | Christmas Ale                  | simlarity=0.785
#    63 | Anchor Steam Beer              | simlarity=0.780
#  2081 | Winter Solstice Seasonal Ale   | simlarity=0.777
#  8297 | Samuel Adams White Ale         | simlarity=0.777
# 15881 | Nugget Nectar                  | simlarity=0.775
# 34877 | Collaboration Not Litigation Ale | simlarity=0.775
#  4202 | Hell Or High Watermelon Wheat Beer | simlarity=0.775
#   794 | Amber Ale                      | simlarity=0.773
# 38365 | Samuel Adams Irish Red         | simlarity=0.771
#  1163 | Belhaven Scottish Ale          | simlarity=0.769
#  1180 | Raison D'Être                  | simlarity=0.767
# 35738 | Hop Stoopid                    | simlarity=0.765
#   129 | Orval Trappist Ale             | simlarity=0.760
# 28165 | Bender                         | simlarity=0.749
#   146 | Brooklyn Brown Ale             | simlarity=0.746
#   576 | Nut Brown Ale                  | simlarity=0.744
#  1963 | Spotted Cow                    | simlarity=0.744
#  1924 | Best Brown Ale                 | simlarity=0.744
#  2894 | Ellie's Brown Ale              | simlarity=0.741
#  3711 | Censored                       | simlarity=0.739
#    33 | Maudite                        | simlarity=0.735
#  7531 | The Mad Elf                    | simlarity=0.735
#  8951 | OAKED Arrogant Bastard Ale     | simlarity=0.734
# 49789 | A Little Sumpin' Sumpin' Ale   | simlarity=0.732
#  8682 | Winter White Ale               | simlarity=0.729
#  2264 | Brown Shugga'                  | simlarity=0.721
#   607 | Fat Tire Belgian Style Ale     | simlarity=0.717
#  5753 | Fire Rock Pale Ale             | simlarity=0.705
#   945 | Adam                           | simlarity=0.702
#  1446 | Hibernation Ale                | simlarity=0.697
# 45653 | Consecration                   | simlarity=0.695
# 47731 | Maduro Brown Ale               | simlarity=0.695
# 41121 | §ucaba                         | simlarity=0.695
#   103 | Samuel Adams Summer Ale        | simlarity=0.694
#  1745 | Duchesse De Bourgogne          | simlarity=0.694
#   560 | Fuller's 1845                  | simlarity=0.690
#   199 | Immort Ale                     | simlarity=0.689
#  6322 | Hopback Amber Ale              | simlarity=0.689
#  1579 | Olde GnarlyWine                | simlarity=0.688
#  1566 | Blithering Idiot               | simlarity=0.688
#   705 | Harvest Ale (Limited Edition)  | simlarity=0.687
#  1056 | Double Bastard Ale             | simlarity=0.686
#  2678 | Horn Dog Barley Wine Style Ale | simlarity=0.686
#  6533 | Olde School Barleywine         | simlarity=0.685
#  1891 | Third Coast Old Ale            | simlarity=0.685
#  1490 | Hog Heaven: Imperial Red IPA   | simlarity=0.684
# 20931 | Old Ruffian Barley Wine        | simlarity=0.683
#  2965 | XS Old Crustacean              | simlarity=0.682
#  1009 | Old Horizontal                 | simlarity=0.682
#  2671 | Bigfoot Barleywine-Style Ale   | simlarity=0.680
#  1445 | Old Foghorn                    | simlarity=0.679
#   577 | Winter Welcome Ale             | simlarity=0.674
#   184 | Old Brown Dog                  | simlarity=0.670
#   751 | 420 Extra Pale Ale             | simlarity=0.668
# 30970 | He'Brew Bittersweet Lenny's R.I.P.A. | simlarity=0.668
#  1576 | Christmas Ale                  | simlarity=0.668
# 35397 | Lucky 13 Mondo Large Red Ale   | simlarity=0.665
#   459 | Fred                           | simlarity=0.664
#  3158 | Hop Rod Rye                    | simlarity=0.662
#  1798 | Boddingtons Pub Ale            | simlarity=0.656
# 27804 | Houblon Chouffe Dobbelen IPA Tripel | simlarity=0.655
#   811 | Bass Pale Ale                  | simlarity=0.654
#   245 | Fraoch Heather Ale             | simlarity=0.653
# 48582 | Daisy Cutter Pale Ale          | simlarity=0.648
#  2533 | The Hairy Eyeball              | simlarity=0.646
#   639 | Newcastle Brown Ale            | simlarity=0.644
#  1173 | Santa's Private Reserve Ale    | simlarity=0.643
#   637 | Old Speckled Hen               | simlarity=0.642
# 29602 | Smithwick's Imported Premium Irish Ale | simlarity=0.639
#  1881 | Samuel Adams Old Fezziwig Ale  | simlarity=0.638
#  1655 | Red Rocket Ale                 | simlarity=0.635
#  1867 | Old Stock Ale                  | simlarity=0.629
#    92 | Arrogant Bastard Ale           | simlarity=0.628
#   575 | Organic Pale Ale               | simlarity=0.627
#  6590 | Hazed Hoppy Session Ale        | simlarity=0.624
#  1193 | Samuel Adams Boston Ale (Stock Ale) | simlarity=0.623
#  7597 | Pure Hoppiness                 | simlarity=0.619
# 89174 | Grapefruit Sculpin             | simlarity=0.615
#  9478 | Gumballhead                    | simlarity=0.614
#   299 | #9                             | simlarity=0.610
#   222 | Fuller's London Pride          | simlarity=0.607
# 56613 | Wilco Tango Foxtrot            | simlarity=0.606
#  5653 | DBA (Double Barrel Ale)        | simlarity=0.603
# 36727 | Green Flash Le Freak           | simlarity=0.596
# 48385 | Undercover Investigation Shut-down Ale | simlarity=0.591
# 38470 | Sublimely Self-Righteous Black IPA | simlarity=0.587
#  1161 | Indian Brown Ale               | simlarity=0.584
# 43905 | Cali-Belgique IPA              | simlarity=0.583
# 62645 | Lukcy Basartd Ale              | simlarity=0.583
#  6518 | Dale's Pale Ale                | simlarity=0.583
#   355 | Dead Guy Ale                   | simlarity=0.580
#   195 | Mirror Pond Pale Ale           | simlarity=0.578
# 148052 | Hop Hunter                     | simlarity=0.576
# 57912 | A Little Sumpin' Wild          | simlarity=0.574
#  1157 | Honker's Ale                   | simlarity=0.574
# 35732 | Hop Head Red Ale               | simlarity=0.570
#  1792 | Nosferatu                      | simlarity=0.568
#   225 | Burning River Pale Ale         | simlarity=0.562
#   573 | India Ale                      | simlarity=0.561
#   361 | Brutal                         | simlarity=0.560
# 44755 | Leviathan Imperial IPA         | simlarity=0.559
# 33243 | Wipeout IPA                    | simlarity=0.558
# 22527 | 471 Small Batch IPA            | simlarity=0.557
# 71969 | Perpetual IPA                  | simlarity=0.557
# 55081 | Ranger                         | simlarity=0.557
# 22381 | Dark Horse Double Crooked Tree IPA | simlarity=0.557
#   410 | Ruedrich's Red Seal Ale        | simlarity=0.555
# 35754 | Double Dog Double IPA          | simlarity=0.554
# 64228 | Zombie Dust                    | simlarity=0.553
#  5385 | Dark Horse Crooked Tree IPA    | simlarity=0.552
#  7284 | Double IPA                     | simlarity=0.551
# 31323 | Hop 15                         | simlarity=0.551
# 17060 | Hercules Double IPA            | simlarity=0.550
# 52531 | Arctic Panzer Wolf             | simlarity=0.550
# 12322 | Mojo IPA                       | simlarity=0.549
# 46363 | Jai Alai IPA                   | simlarity=0.549
#   311 | IPA                            | simlarity=0.549
# 34085 | Green Flash Imperial India Pale Ale | simlarity=0.548
#  1372 | Maximus                        | simlarity=0.548
#  9086 | 120 Minute IPA                 | simlarity=0.548
# 16814 | Heady Topper                   | simlarity=0.547
#    39 | Alpha King                     | simlarity=0.547
# 117177 | Sip Of Sunshine                | simlarity=0.547
# 46385 | Yakima Glory                   | simlarity=0.546
#  2729 | Avery India Pale Ale (IPA)     | simlarity=0.546
# 18421 | Lake Erie Monster              | simlarity=0.546
# 46849 | Abrasive Ale                   | simlarity=0.546
# 20470 | Stoudt's Double IPA (India Pale Ale) | simlarity=0.545
# 38180 | Union Jack IPA                 | simlarity=0.545
# 47434 | Hop Henge                      | simlarity=0.544
# 28577 | Unearthly (Imperial India Pale Ale) | simlarity=0.544
# 34146 | Double Trouble                 | simlarity=0.543
#  6549 | Northern Hemisphere Harvest Wet Hop IPA | simlarity=0.543
# 53886 | Terrapin Hopsecutioner         | simlarity=0.542
#  1493 | Sweetwater IPA                 | simlarity=0.542
#  3968 | Goose IPA                      | simlarity=0.542
# 52855 | Raging Bitch Belgian-Style IPA | simlarity=0.541
# 48243 | Modus Hoperandi                | simlarity=0.541
# 42533 | Sierra Nevada Southern Hemisphere Harvest Fresh Hop IPA | simlarity=0.540
#  8919 | G'Knight                       | simlarity=0.540
# 35626 | Odell IPA                      | simlarity=0.539
#   358 | XS Imperial India Pale Ale     | simlarity=0.539
#  1213 | Doggie Style Classic Pale Ale  | simlarity=0.539
# 10386 | Dorado                         | simlarity=0.539
# 60330 | Fresh Squeezed IPA             | simlarity=0.538
#  9088 | IPA (India Pale Ale)           | simlarity=0.536
#  5441 | Centennial IPA                 | simlarity=0.536
# 20781 | Brew Free Or Die IPA           | simlarity=0.536
# 29209 | Inversion IPA                  | simlarity=0.535
# 11922 | Titan IPA                      | simlarity=0.535
# 55412 | Gubna                          | simlarity=0.535
# 21690 | Pliny The Younger              | simlarity=0.535
# 45175 | Palate Wrecker                 | simlarity=0.535
#  1904 | Celebration Fresh Hop IPA      | simlarity=0.535
#   205 | Snake Dog IPA                  | simlarity=0.534
# 16403 | Smuttynose IPA "Finest Kind"   | simlarity=0.534
# 17900 | Short's Huma Lupa Licious India Pale Ale | simlarity=0.533
# 25259 | Hopsickle Imperial India Pale Ale | simlarity=0.533
# 68916 | Lunch                          | simlarity=0.533
#   611 | Hop Ottin' IPA                 | simlarity=0.533
# 49838 | Squall IPA                     | simlarity=0.533
# 22352 | Maharaja                       | simlarity=0.533
#  6076 | Flower Power India Pale Ale    | simlarity=0.532
# 58914 | All Day IPA                    | simlarity=0.532
# 57252 | Samuel Adams Latitude 48 IPA   | simlarity=0.532
#   665 | Anchor Liberty Ale             | simlarity=0.531
# 34688 | Redhook Long Hammer IPA        | simlarity=0.530
#   709 | Big Eye                        | simlarity=0.529
# 30288 | Double Simcoe IPA              | simlarity=0.529
# 27604 | Duet                           | simlarity=0.528
# 30420 | Torpedo Extra IPA              | simlarity=0.528
#  1558 | Dreadnaught IPA                | simlarity=0.528
#  1005 | HopDevil India Pale Ale        | simlarity=0.528
# 52361 | The Oracle                     | simlarity=0.527
# 72170 | Pseudo Sue                     | simlarity=0.527
#  2751 | Racer 5 India Pale Ale         | simlarity=0.526
# 57908 | 2XIPA                          | simlarity=0.526
#  6108 | 60 Minute IPA                  | simlarity=0.525
# 55939 | Hoptimum                       | simlarity=0.525
#   916 | Lagunitas IPA                  | simlarity=0.525
# 82250 | RuinTen Triple IPA             | simlarity=0.524
# 22505 | West Coast IPA                 | simlarity=0.523
# 20478 | Harvest Ale                    | simlarity=0.522
#    88 | IPA                            | simlarity=0.522
# 84596 | Enjoy By IPA                   | simlarity=0.521
# 28203 | Furious                        | simlarity=0.521
#  1575 | Commodore Perry IPA            | simlarity=0.520
# 29619 | Sculpin IPA                    | simlarity=0.519
# 18862 | Burton Baton                   | simlarity=0.518
#   147 | Brooklyn East India Pale Ale   | simlarity=0.518
# 22790 | Blind Pig IPA                  | simlarity=0.517
# 25755 | Loose Cannon Hop3 IPA          | simlarity=0.516
# 99873 | DirtWolf                       | simlarity=0.516
# 77299 | Resin                          | simlarity=0.513
# 32286 | Nelson                         | simlarity=0.512
#  2093 | 90 Minute IPA                  | simlarity=0.508
#   276 | Sierra Nevada Pale Ale         | simlarity=0.506
#  7971 | Pliny The Elder                | simlarity=0.506
#  1093 | Two Hearted Ale                | simlarity=0.505
#  3916 | IPA                            | simlarity=0.500
# 17112 | Hopslam Ale                    | simlarity=0.495
#   680 | Brooklyn Black Chocolate Stout | simlarity=-1.000
# tensor([458,  60, 496, 464, 258, 412, 153, 427, 302, 146, 201, 398, 240, 444,
#         114,  66, 446, 494, 448, 325, 298, 397, 182, 346, 347, 342,  76, 345,
#          37, 154, 152, 317, 128, 394, 436, 216, 264, 348, 388, 391, 239, 351,
#         386, 481, 473, 178, 445,  39,  84,  13, 429, 135, 242, 439, 320, 313,
#         103, 416, 357, 425,  96, 122, 433, 477, 461, 392, 375, 355, 423, 208,
#         229, 424, 275, 304, 123, 327, 316, 383, 222, 323, 428, 189, 396, 455,
#         432, 333, 296, 475, 130,  47, 277,  45, 233,   2, 213, 414, 119, 207,
#          16, 133, 370,  64, 265, 101, 106, 138, 246,  97,  85, 312, 389, 295,
#         364, 118, 102, 194, 109, 281, 221, 262, 168, 173,  40, 401, 431,  10,
#         352, 107,  79, 198, 331,  49,  43,  59,  27, 440, 156, 170,  24, 254,
#           9, 179, 454, 212, 166, 223, 273, 117, 241, 209, 124, 256, 148, 104,
#         125, 243, 143, 227, 292,  12, 132, 310, 406, 235,  56, 404, 358,  90,
#         197, 127, 120, 402, 167,   3,  93, 422,  26, 269, 180, 330, 175, 196,
#         376,  71, 450, 111, 283, 171,  52, 203,  63, 250, 315, 245, 134, 169,
#         205, 341, 174, 260, 139, 172,  14, 199,   7, 225,  28, 338,  78, 410,
#         181,  83, 418, 285, 318,  19, 113, 368,  77, 272, 147,  21, 126, 176,
#         261, 286, 324, 226,  73,   4,  91, 421, 164,  50,  18, 344,   5, 112,
#         214, 145, 271, 457,  29, 204, 469, 219, 489,   1, 230, 141,  72,  70,
#          98, 297, 259, 202, 187,  32, 451, 322,  57, 293, 365, 188,  53, 462,
#         280, 413, 490, 380, 155,  34,  82, 238, 237, 267,  44,  23,  69,  20,
#         343,  35, 336, 151, 158,   0,  75, 257, 234,  54,  51, 483, 463, 328,
#         108,  33,  92, 136, 420,  11, 231, 303, 326, 400, 270, 129, 417, 160,
#         162, 408,  25, 372,  30,  88, 228, 224, 252, 263,   6, 299, 307, 459,
#         305, 236,  94, 279, 140, 184, 438, 449, 426,  22, 206,  81,  41, 287,
#         195, 191, 115, 149, 248, 289, 218, 185, 354, 253, 144, 247, 183,  89,
#          36, 121, 384, 193, 403,  80, 255, 211, 371, 131,  55, 456, 244, 100,
#         161,  99, 378, 217, 200, 215,  17,  87, 291, 163, 300, 495, 311,  61,
#          46, 474, 278, 411, 453, 419, 159, 434, 484, 288,  65,  38, 499, 479,
#         157, 407, 210,  48,  86,  68, 435, 390, 362, 487, 470, 360,  74, 409,
#         485, 274, 294, 385, 334, 466, 321, 441,  62, 393, 177, 308, 332,   8,
#         498, 442, 249, 339, 443, 349, 415, 447, 374, 395, 290, 468, 186, 268,
#         467, 452, 430, 306, 405,  67, 165, 314, 482, 309, 276, 353, 377, 319,
#         471, 356, 437, 220,  42, 329, 337, 366, 486,  95, 460, 359, 282, 480,
#         476, 105, 399, 116, 381, 369, 382, 190, 142, 465, 488, 251, 478, 284,
#         472, 137, 492, 361, 350,  15, 493, 373, 192, 379, 340,  31, 363, 367,
#         497, 491, 387, 232,  58, 301, 150, 266, 335, 110], device='mps:0')

# %% [markdown]
# ## Execute Sanity‑Check Query Suite
#
# A set of eleven representative flavor‑profile queries (e.g., “imperial stout roasted chocolate espresso,” “ipa juicy citrus piney,” “raspberry sour tart lemon”) is defined in `SANITY_QUERIES`. Loops over each query and invokes `getTopKSimilarBeersByQuery(query, topK=15)` to list the top 15 recommendations. Visual inspection confirmed that the returned beers closely match the intended flavor profiles, validating the model’s ability to surface genuinely similar and dissimilar beers.

# %%
SANITY_QUERIES = {
    "q1":  "imperial stout roasted chocolate espresso",
    "q2":  "ipa juicy citrus piney",
    "q3":  "hefeweizen german",
    "q4":  "belgian tripel apricot spicy vanilla",
    "q5":  "pumpkin cinnamon vanilla",
    "q6":  "smoked porter coffee cocoa roast",
    "q7":  "raspberry sour tart lemon",
    "q8":  "bourbon barrel aged stout roasty malty",
    "q9":  "roasty malty smooth",
    "q10": "pilsner pale citrus lemon",
    "q11": "heineken lager",
}

# finding similar beer based on beer -> passed sanity check
for style, query in SANITY_QUERIES.items():
    print(f"recommendations for: {query}")
    getTopKSimilarBeersByQuery(query, topK=15)
    print('')
# Out:
# recommendations for: imperial stout roasted chocolate espresso
#   754 | Guinness Draught               | simlarity=0.999
# 41702 | Theobroma                      | simlarity=0.999
# 16062 | Brewer's Reserve Bourbon Barrel Stout | simlarity=0.999
#  2010 | Java Stout                     | simlarity=0.998
#  8322 | New Holland The Poet           | simlarity=0.998
# 14309 | Samuel Adams Chocolate Bock    | simlarity=0.998
# 10672 | Bourbon County Brand Stout     | simlarity=0.998
#  5428 | Dragon's Milk                  | simlarity=0.997
# 40058 | Choklat (Blackwater Series)    | simlarity=0.997
# 43670 | Bourbon Barrel Quad Barrel-Aged Ale (BBQ) | simlarity=0.994
# 16909 | Curieux                        | simlarity=0.994
# 28877 | Beer Geek Breakfast            | simlarity=0.993
# 30764 | Coffee Bender                  | simlarity=0.992
# 50176 | Chocolate Oak Aged Yeti        | simlarity=0.992
#   224 | Schneider Weisse Tap 6 Unser Aventinus | simlarity=0.991
#
# recommendations for: ipa juicy citrus piney
#  3158 | Hop Rod Rye                    | simlarity=0.997
# 30970 | He'Brew Bittersweet Lenny's R.I.P.A. | simlarity=0.995
# 16074 | Red's Rye IPA                  | simlarity=0.994
# 35738 | Hop Stoopid                    | simlarity=0.993
# 89174 | Grapefruit Sculpin             | simlarity=0.990
#  7597 | Pure Hoppiness                 | simlarity=0.989
#  3951 | ApriHop                        | simlarity=0.985
# 15881 | Nugget Nectar                  | simlarity=0.984
# 27804 | Houblon Chouffe Dobbelen IPA Tripel | simlarity=0.983
# 49789 | A Little Sumpin' Sumpin' Ale   | simlarity=0.983
# 43905 | Cali-Belgique IPA              | simlarity=0.982
# 148052 | Hop Hunter                     | simlarity=0.981
# 76816 | Sierra Nevada Ruthless Rye IPA | simlarity=0.981
# 57912 | A Little Sumpin' Wild          | simlarity=0.981
#  5948 | Terrapin Rye Pale Ale          | simlarity=0.980
#
# recommendations for: hefeweizen german
#   924 | Franziskaner Hefe-Weisse Dunkel | simlarity=1.000
# 48434 | Kellerweis                     | simlarity=0.999
#   132 | Ayinger Bräu Weisse            | simlarity=0.999
#  1256 | Paulaner Hefe-Weissbier Naturtrüb | simlarity=0.999
#  1946 | Franziskaner Hefe-Weisse       | simlarity=0.999
#   772 | Hacker-Pschorr Hefe Weisse Naturtrüb | simlarity=0.998
#  3280 | Schneider Weisse Tap 7 Unser Original | simlarity=0.998
#  2249 | Hefeweizen                     | simlarity=0.998
#   731 | Weihenstephaner Hefeweissbier  | simlarity=0.998
#  2434 | Erdinger Weissbier             | simlarity=0.998
#    17 | Widmer Hefeweizen              | simlarity=0.998
# 14309 | Samuel Adams Chocolate Bock    | simlarity=0.990
#   727 | Aecht Schlenkerla Rauchbier Märzen | simlarity=0.990
#  1932 | Pumpkinhead Ale                | simlarity=0.989
# 38394 | Pumking                        | simlarity=0.989
#
# recommendations for: belgian tripel apricot spicy vanilla
#  1855 | Prior 8                        | simlarity=1.000
#   857 | Trappist Westvleteren 8 (VIII) | simlarity=1.000
#  2566 | Maredsous 10 - Triple          | simlarity=0.999
#  9689 | White Rascal                   | simlarity=0.999
#  2137 | Leffe Blonde                   | simlarity=0.999
#   674 | Westmalle Trappist Dubbel      | simlarity=0.999
#  6073 | Merry Monks                    | simlarity=0.998
#  1545 | Trappist Westvleteren 12 (XII) | simlarity=0.998
#  3842 | Trappistes Rochefort 6         | simlarity=0.998
#    59 | White                          | simlarity=0.998
#  1346 | Chimay Tripel (White)          | simlarity=0.997
#    10 | Dubbel Ale                     | simlarity=0.997
#   646 | Westmalle Trappist Tripel      | simlarity=0.997
#   722 | Tripel                         | simlarity=0.996
#   449 | Stella Artois                  | simlarity=0.996
#
# recommendations for: pumpkin cinnamon vanilla
#   727 | Aecht Schlenkerla Rauchbier Märzen | simlarity=0.999
#    74 | Post Road Pumpkin Ale          | simlarity=0.999
#  1932 | Pumpkinhead Ale                | simlarity=0.999
# 25880 | Imperial Pumpkin Ale           | simlarity=0.999
# 38394 | Pumking                        | simlarity=0.999
#  6260 | Punkin Ale                     | simlarity=0.999
# 11819 | Pumpkin Ale                    | simlarity=0.999
#   100 | Blue Moon Harvest Moon Pumpkin Ale | simlarity=0.999
#   224 | Schneider Weisse Tap 6 Unser Aventinus | simlarity=0.998
#   760 | Weihenstephaner Kristallweissbier | simlarity=0.997
#  1324 | Aecht Schlenkerla Rauchbier Urbock | simlarity=0.997
# 35625 | Weihenstephaner Vitus          | simlarity=0.997
#   712 | Weihenstephaner Original       | simlarity=0.996
#   779 | Weihenstephaner Korbinian      | simlarity=0.996
#  1008 | Moonglow Weizenbock            | simlarity=0.995
#
# recommendations for: smoked porter coffee cocoa roast
#  7438 | Alpha Klaus Christmas (Xmas) Porter | simlarity=0.999
#  1769 | Alaskan Smoked Porter          | simlarity=0.998
#    90 | Smoked Porter                  | simlarity=0.997
# 27800 | Vanilla Porter                 | simlarity=0.995
# 37795 | Coconut Hiwa Porter            | simlarity=0.994
# 20564 | Samuel Adams Holiday Porter    | simlarity=0.993
#   206 | Road Dog Porter                | simlarity=0.993
# 33183 | Pipeline Porter                | simlarity=0.993
# 24071 | Gonzo Imperial Porter          | simlarity=0.993
#  7348 | Porter                         | simlarity=0.993
#   226 | Edmund Fitzgerald Porter       | simlarity=0.993
#   279 | Porter                         | simlarity=0.993
#   572 | Taddy Porter                   | simlarity=0.993
#  1287 | Porter                         | simlarity=0.993
#    61 | Anchor Porter                  | simlarity=0.992
#
# recommendations for: raspberry sour tart lemon
#   108 | Samuel Adams Cherry Wheat      | simlarity=1.000
#  3089 | Raison D'Extra                 | simlarity=1.000
#   837 | Coors Light                    | simlarity=1.000
#   246 | Heineken Lager Beer            | simlarity=1.000
#  6715 | Budweiser Budvar B:Original    | simlarity=1.000
#    65 | Budweiser                      | simlarity=1.000
#   580 | Miller High Life               | simlarity=1.000
#   599 | Lindemans Framboise            | simlarity=1.000
#  1632 | Cantillon Kriek 100% Lambic    | simlarity=1.000
#  1352 | Shiner Bock                    | simlarity=1.000
# 47785 | Samuel Adams Double Bock (Imperial Series) | simlarity=1.000
#   332 | Miller Lite                    | simlarity=1.000
#  4109 | Troegenator                    | simlarity=1.000
#  1276 | Coors Banquet                  | simlarity=1.000
#  3635 | La Terrible                    | simlarity=1.000
#
# recommendations for: bourbon barrel aged stout roasty malty
#  1914 | 1554 Black Lager               | simlarity=0.999
# 16909 | Curieux                        | simlarity=0.999
# 30764 | Coffee Bender                  | simlarity=0.999
# 43670 | Bourbon Barrel Quad Barrel-Aged Ale (BBQ) | simlarity=0.999
# 10672 | Bourbon County Brand Stout     | simlarity=0.998
#  8322 | New Holland The Poet           | simlarity=0.998
# 16062 | Brewer's Reserve Bourbon Barrel Stout | simlarity=0.998
#  5428 | Dragon's Milk                  | simlarity=0.997
#   754 | Guinness Draught               | simlarity=0.997
#  5488 | Wells Banana Bread Beer        | simlarity=0.996
#   808 | Weihenstephaner Hefeweissbier Dunkel | simlarity=0.996
# 56973 | Shakespeare Oatmeal Stout      | simlarity=0.995
#    10 | Dubbel Ale                     | simlarity=0.994
#   667 | Negra Modelo                   | simlarity=0.993
#  1545 | Trappist Westvleteren 12 (XII) | simlarity=0.993
#
# recommendations for: roasty malty smooth
#   580 | Miller High Life               | simlarity=1.000
#    65 | Budweiser                      | simlarity=1.000
#  6715 | Budweiser Budvar B:Original    | simlarity=1.000
#   246 | Heineken Lager Beer            | simlarity=1.000
#   837 | Coors Light                    | simlarity=1.000
#  1276 | Coors Banquet                  | simlarity=1.000
#  4109 | Troegenator                    | simlarity=1.000
#  1585 | Raspberry Tart                 | simlarity=1.000
# 29015 | Leinenkugel's Sunset Wheat     | simlarity=1.000
#   599 | Lindemans Framboise            | simlarity=1.000
# 47785 | Samuel Adams Double Bock (Imperial Series) | simlarity=1.000
#  6104 | Grand Cru Oude Gueuze Cuvée René | simlarity=1.000
#   108 | Samuel Adams Cherry Wheat      | simlarity=1.000
#  1703 | Cantillon Gueuze 100% Lambic   | simlarity=1.000
#  2557 | Cantillon Rosé De Gambrinus    | simlarity=1.000
#
# recommendations for: pilsner pale citrus lemon
# 48139 | Mama's Little Yella Pils       | simlarity=1.000
#  5948 | Terrapin Rye Pale Ale          | simlarity=1.000
# 76816 | Sierra Nevada Ruthless Rye IPA | simlarity=1.000
#   402 | Skull Splitter                 | simlarity=0.999
# 37774 | Schneider Weisse Tap 5 Schneider & Brooklyner Hopfenweisse | simlarity=0.999
# 74986 | Lagunitas Sucks                | simlarity=0.999
#  3951 | ApriHop                        | simlarity=0.999
#  7463 | Dirty Bastard                  | simlarity=0.999
#     7 | Purple Haze                    | simlarity=0.998
#   582 | Spaten Oktoberfestbier Ur-Märzen | simlarity=0.998
#  1017 | Festbier                       | simlarity=0.998
# 54904 | Samuel Adams Noble Pils        | simlarity=0.998
# 19589 | Lagunitas PILS (Czech Style Pilsner) | simlarity=0.998
#    99 | Spaten Optimator               | simlarity=0.998
#  1010 | Prima Pils                     | simlarity=0.998
#
# recommendations for: heineken lager
#    65 | Budweiser                      | simlarity=1.000
#  6715 | Budweiser Budvar B:Original    | simlarity=1.000
#   580 | Miller High Life               | simlarity=1.000
#   246 | Heineken Lager Beer            | simlarity=1.000
#   837 | Coors Light                    | simlarity=1.000
#  1276 | Coors Banquet                  | simlarity=1.000
#   108 | Samuel Adams Cherry Wheat      | simlarity=1.000
#  4109 | Troegenator                    | simlarity=1.000
#   599 | Lindemans Framboise            | simlarity=1.000
#  1585 | Raspberry Tart                 | simlarity=1.000
# 29015 | Leinenkugel's Sunset Wheat     | simlarity=1.000
# 47785 | Samuel Adams Double Bock (Imperial Series) | simlarity=1.000
#  6104 | Grand Cru Oude Gueuze Cuvée René | simlarity=1.000
#  1352 | Shiner Bock                    | simlarity=1.000
#  1703 | Cantillon Gueuze 100% Lambic   | simlarity=1.000

# %% [markdown]
# ## Save Trained Autoencoder Model
#
# Sets the model to evaluation mode, uses TorchScript to script (freeze) the autoencoder into `scripted_model`, and saves it as `beer_autoencoder_frozen.pt` for efficient deployment and later inference.

# %%
# save trained model
model.eval()
scripted_model = torch.jit.script(model)
scripted_model.save("beer_autoencoder_frozen.pt")

# %% [markdown]
# ## Save Beer Embeddings
#
# Moves the `beerEmbeddings` tensor to CPU and persists it to `beer_embeddings_autoencoder.pt` using `torch.save` for downstream recommendation inference.

# %%
# save trained beer autoencoder
beerEmbeddings = beerEmbeddings.cpu()       # move to CPU if on GPU/MPS
torch.save(beerEmbeddings, "beer_embeddings_autoencoder.pt")

# %% [markdown]
# ## Save TF‑IDF Vectorizer
#
# Pickles the trained `vectorizer` to `tfidf_vectorizer.pkl` for later reuse in transforming text inputs during inference.

# %%
import pickle

with open("tfidf_vectorizer.pkl", "wb") as f:
    pickle.dump(vectorizer, f)
